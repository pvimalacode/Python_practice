# %% [markdown]
# Q.3 [4 marks] <br>
# Using lists only, create 3 records of 3 students; each record includes the student’s last name <br>andher 3 grades. You start from an empty list then append the data into it. Last, your program<br> should calculate the average of each student and create a new single record in the same list that<br> include the names of the students and their averages.<br>

# %%
std1_grades= []
std2_grades= []
std3_grades= []
n=3
#Student 1 data given below

std1_name = input('Enter the last name of student 1 :')
std1_info = [std1_name]
#n = int(input("Enter number of subjects for student1: "))
for i in range(0, n):
    print("Enter subject",i+1, "grade" )
    std1_grades = int(input())
    std1_info.append(std1_grades)
    
avg_std1 = std1_info[1:]    
n_size = len(avg_std1)
avg1_grades = sum(avg_std1)/n_size
print()

print("1st student name along with the grades is ", std1_info)
#print("Average grades of student 1 ", avg1_grades)
print("Average grades of student 1: ", "{:.2f}".format(avg1_grades))
std1_info1 = [std1_name,round(avg1_grades,2)]





#student 2 data given below

std2_name = input('Enter the last name of student 2 : ')
std2_info = [std2_name]
#n = int(input("Enter number of subjects for student2: "))
#n = 3
for i in range(0, n):
    print("Enter subject",i+1, "grade" )
    std2_grades = int(input())
    std2_info.append(std2_grades)
    
    
avg_std2 = std2_info[1:]    
n1_size = len(avg_std2)
avg2_grades = sum(avg_std2)/n1_size
print()

print("2nd student name along with the grades is ", std2_info)
#print("Average grades of student 2 ", avg2_grades)
print("Average grades of student 2: ", "{:.2f}".format(avg2_grades))
std2_info2 = [std2_name,round(avg2_grades,2)] #will be used for later stuff




#student 3 data given below

std3_name = input('Enter the last name of student 3 : ')
std3_info = [std3_name]
#n = int(input("Enter number of subjects for student 3: "))
for i in range(0, n):
    print("Enter subject",i+1," grade" )
    std3_grades = int(input())
    std3_info.append(std3_grades)
    
    
avg_std3 = std3_info[1:]    
n2_size = len(avg_std3)
avg3_grades = sum(avg_std3)/n2_size
print()

print("3rd student name along with the grades is ", std3_info)
#print("Average grades of student 3 ", avg3_grades)
print("Average grades of student 3: ", "{:.2f}".format(round(avg3_grades),2))
std3_info3 = [std3_name,round(avg3_grades,2)]


#final_list = [std1_info1,std2_info2,std3_info3]
final_list = [[std1_info,std2_info,std3_info],[*std1_info1,*std2_info2,*std3_info3]]
print()
print()
print("--------------------------------------------------------------------------------------------------------------------")
print("Names of all the students along with their average grades\n",final_list)
print("---------------------------------------------------------------------------------------------------------------------")
# Out:
# Enter subject 1 grade
# Enter subject 2 grade
# Enter subject 3 grade
#
# 1st student name along with the grades is  ['stu1', 89, 98, 78]
# Average grades of student 1:  88.33
# Enter subject 1 grade
# Enter subject 2 grade
# Enter subject 3 grade
#
# 2nd student name along with the grades is  ['stu2', 98, 67, 87]
# Average grades of student 2:  84.00
# Enter subject 1  grade
# Enter subject 2  grade
# Enter subject 3  grade
#
# 3rd student name along with the grades is  ['stu3', 98, 78, 65]
# Average grades of student 3:  80.00
#
#
# --------------------------------------------------------------------------------------------------------------------
# Names of all the students along with their average grades
#  [[['stu1', 89, 98, 78], ['stu2', 98, 67, 87], ['stu3', 98, 78, 65]], ['stu1', 88.33, 'stu2', 84.0, 'stu3', 80.33]]
# ---------------------------------------------------------------------------------------------------------------------
