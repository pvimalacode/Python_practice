# %%
from sklearn.linear_model import LinearRegression
from sklearn.datasets import load_boston

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score,mean_absolute_error



import pandas as pd
import numpy as np

# %%
boston_housing = load_boston()
type(boston_housing)
# Out:
# sklearn.utils.Bunch

# %%
print(boston_housing.DESCR)
# Out:
# .. _boston_dataset:
#
# Boston house prices dataset
# ---------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 506
#
#     :Number of Attributes: 13 numeric/categorical predictive. Median Value (attribute 14) is usually the target.
#
#     :Attribute Information (in order):
#         - CRIM     per capita crime rate by town
#         - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.
#         - INDUS    proportion of non-retail business acres per town
#         - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
#         - NOX      nitric oxides concentration (parts per 10 million)
#         - RM       average number of rooms per dwelling
#         - AGE      proportion of owner-occupied units built prior to 1940
#         - DIS      weighted distances to five Boston employment centres
#         - RAD      index of accessibility to radial highways
#         - TAX      full-value property-tax rate per $10,000
#         - PTRATIO  pupil-teacher ratio by town
#         - B        1000(Bk - 0.63)^2 where Bk is the proportion of black people by town
#         - LSTAT    % lower status of the population
#         - MEDV     Median value of owner-occupied homes in $1000's
#
#     :Missing Attribute Values: None
#
#     :Creator: Harrison, D. and Rubinfeld, D.L.
#
# This is a copy of UCI ML housing dataset.
# https://archive.ics.uci.edu/ml/machine-learning-databases/housing/
#
#
# This dataset was taken from the StatLib library which is maintained at Carnegie Mellon University.
#
# The Boston house-price data of Harrison, D. and Rubinfeld, D.L. 'Hedonic
# prices and the demand for clean air', J. Environ. Economics & Management,
# vol.5, 81-102, 1978.   Used in Belsley, Kuh & Welsch, 'Regression diagnostics
# ...', Wiley, 1980.   N.B. Various transformations are used in the table on
# pages 244-261 of the latter.
#
# The Boston house-price data has been used in many machine learning papers that address regression
# problems.
#
# .. topic:: References
#
#    - Belsley, Kuh & Welsch, 'Regression diagnostics: Identifying Influential Data and Sources of Collinearity', Wiley, 1980. 244-261.
#    - Quinlan,R. (1993). Combining Instance-Based and Model-Based Learning. In Proceedings on the Tenth International Conference of Machine Learning, 236-243, University of Massachusetts, Amherst. Morgan Kaufmann.

# %%
df_boston=pd.DataFrame(boston_housing.data)
df_boston.columns=boston_housing.feature_names
df_boston.rename(columns = {'CRIM' : 'Crime_Rate', 'ZN' : 'Residential_Zone', 'INDUS':'Business_Area',\
    'CHAS':'Bound','NOX':'Nitric_Oxide','RM':'Avg_Rooms','AGE':'Old_Units','DIS':'Emp_Center','RAD':'Highway',\
        'TAX':'Tax','PTRATIO':'Stu_Teach','B':'Black_Prop','LSTAT':'Low_Sts'}, inplace = True)
df_boston['Target'] = boston_housing['target']

df_boston.head()
# Out:
#    Crime_Rate  Residential_Zone  Business_Area  Bound  Nitric_Oxide  \
# 0     0.00632              18.0           2.31    0.0         0.538
# 1     0.02731               0.0           7.07    0.0         0.469
# 2     0.02729               0.0           7.07    0.0         0.469
# 3     0.03237               0.0           2.18    0.0         0.458
# 4     0.06905               0.0           2.18    0.0         0.458
#
#    Avg_Rooms  Old_Units  Emp_Center  Highway    Tax  Stu_Teach  Black_Prop  \
# 0      6.575       65.2      4.0900      1.0  296.0       15.3      396.90
# 1      6.421       78.9      4.9671      2.0  242.0       17.8      396.90
# 2      7.185       61.1      4.9671      2.0  242.0       17.8      392.83
# 3      6.998       45.8      6.0622      3.0  222.0       18.7      394.63
# 4      7.147       54.2      6.0622      3.0  222.0       18.7      396.90
#
#    Low_Sts  Target
# 0     4.98    24.0
# 1     9.14    21.6
# 2     4.03    34.7
# 3     2.94    33.4
# 4     5.33    36.2

# %%
abs(df_boston.corr()['Target'][:]).sort_values(ascending=False)
# Out:
# Target              1.000000
# Low_Sts             0.737663
# Avg_Rooms           0.695360
# Stu_Teach           0.507787
# Business_Area       0.483725
# Tax                 0.468536
# Nitric_Oxide        0.427321
# Crime_Rate          0.388305
# Highway             0.381626
# Old_Units           0.376955
# Residential_Zone    0.360445
# Black_Prop          0.333461
# Emp_Center          0.249929
# Bound               0.175260
# Name: Target, dtype: float64

# %%
for col in df_boston.columns[:-1]:
    print(col,':')
    print(abs(df_boston.corr()[col][:]).sort_values(ascending=False),end='\n\n')
# Out:
# Crime_Rate :
# Crime_Rate          1.000000
# Highway             0.625505
# Tax                 0.582764
# Low_Sts             0.455621
# Nitric_Oxide        0.420972
# Business_Area       0.406583
# Target              0.388305
# Black_Prop          0.385064
# Emp_Center          0.379670
# Old_Units           0.352734
# Stu_Teach           0.289946
# Avg_Rooms           0.219247
# Residential_Zone    0.200469
# Bound               0.055892
# Name: Crime_Rate, dtype: float64
#
# Residential_Zone :
# Residential_Zone    1.000000
# Emp_Center          0.664408
# Old_Units           0.569537
# Business_Area       0.533828
# Nitric_Oxide        0.516604
# Low_Sts             0.412995
# Stu_Teach           0.391679
# Target              0.360445
# Tax                 0.314563
# Avg_Rooms           0.311991
# Highway             0.311948
# Crime_Rate          0.200469
# Black_Prop          0.175520
# Bound               0.042697
# Name: Residential_Zone, dtype: float64
#
# Business_Area :
# Business_Area       1.000000
# Nitric_Oxide        0.763651
# Tax                 0.720760
# Emp_Center          0.708027
# Old_Units           0.644779
# Low_Sts             0.603800
# Highway             0.595129
# Residential_Zone    0.533828
# Target              0.483725
# Crime_Rate          0.406583
# Avg_Rooms           0.391676
# Stu_Teach           0.383248
# Black_Prop          0.356977
# Bound               0.062938
# Name: Business_Area, dtype: float64
#
# Bound :
# Bound               1.000000
# Target              0.175260
# Stu_Teach           0.121515
# Emp_Center          0.099176
# Avg_Rooms           0.091251
# Nitric_Oxide        0.091203
# Old_Units           0.086518
# Business_Area       0.062938
# Crime_Rate          0.055892
# Low_Sts             0.053929
# Black_Prop          0.048788
# Residential_Zone    0.042697
# Tax                 0.035587
# Highway             0.007368
# Name: Bound, dtype: float64
#
# Nitric_Oxide :
# Nitric_Oxide        1.000000
# Emp_Center          0.769230
# Business_Area       0.763651
# Old_Units           0.731470
# Tax                 0.668023
# Highway             0.611441
# Low_Sts             0.590879
# Residential_Zone    0.516604
# Target              0.427321
# Crime_Rate          0.420972
# Black_Prop          0.380051
# Avg_Rooms           0.302188
# Stu_Teach           0.188933
# Bound               0.091203
# Name: Nitric_Oxide, dtype: float64
#
# Avg_Rooms :
# Avg_Rooms           1.000000
# Target              0.695360
# Low_Sts             0.613808
# Business_Area       0.391676
# Stu_Teach           0.355501
# Residential_Zone    0.311991
# Nitric_Oxide        0.302188
# Tax                 0.292048
# Old_Units           0.240265
# Crime_Rate          0.219247
# Highway             0.209847
# Emp_Center          0.205246
# Black_Prop          0.128069
# Bound               0.091251
# Name: Avg_Rooms, dtype: float64
#
# Old_Units :
# Old_Units           1.000000
# Emp_Center          0.747881
# Nitric_Oxide        0.731470
# Business_Area       0.644779
# Low_Sts             0.602339
# Residential_Zone    0.569537
# Tax                 0.506456
# Highway             0.456022
# Target              0.376955
# Crime_Rate          0.352734
# Black_Prop          0.273534
# Stu_Teach           0.261515
# Avg_Rooms           0.240265
# Bound               0.086518
# Name: Old_Units, dtype: float64
#
# Emp_Center :
# Emp_Center          1.000000
# Nitric_Oxide        0.769230
# Old_Units           0.747881
# Business_Area       0.708027
# Residential_Zone    0.664408
# Tax                 0.534432
# Low_Sts             0.496996
# Highway             0.494588
# Crime_Rate          0.379670
# Black_Prop          0.291512
# Target              0.249929
# Stu_Teach           0.232471
# Avg_Rooms           0.205246
# Bound               0.099176
# Name: Emp_Center, dtype: float64
#
# Highway :
# Highway             1.000000
# Tax                 0.910228
# Crime_Rate          0.625505
# Nitric_Oxide        0.611441
# Business_Area       0.595129
# Emp_Center          0.494588
# Low_Sts             0.488676
# Stu_Teach           0.464741
# Old_Units           0.456022
# Black_Prop          0.444413
# Target              0.381626
# Residential_Zone    0.311948
# Avg_Rooms           0.209847
# Bound               0.007368
# Name: Highway, dtype: float64
#
# Tax :
# Tax                 1.000000
# Highway             0.910228
# Business_Area       0.720760
# Nitric_Oxide        0.668023
# Crime_Rate          0.582764
# Low_Sts             0.543993
# Emp_Center          0.534432
# Old_Units           0.506456
# Target              0.468536
# Stu_Teach           0.460853
# Black_Prop          0.441808
# Residential_Zone    0.314563
# Avg_Rooms           0.292048
# Bound               0.035587
# Name: Tax, dtype: float64
#
# Stu_Teach :
# Stu_Teach           1.000000
# Target              0.507787
# Highway             0.464741
# Tax                 0.460853
# Residential_Zone    0.391679
# Business_Area       0.383248
# Low_Sts             0.374044
# Avg_Rooms           0.355501
# Crime_Rate          0.289946
# Old_Units           0.261515
# Emp_Center          0.232471
# Nitric_Oxide        0.188933
# Black_Prop          0.177383
# Bound               0.121515
# Name: Stu_Teach, dtype: float64
#
# Black_Prop :
# Black_Prop          1.000000
# Highway             0.444413
# Tax                 0.441808
# Crime_Rate          0.385064
# Nitric_Oxide        0.380051
# Low_Sts             0.366087
# Business_Area       0.356977
# Target              0.333461
# Emp_Center          0.291512
# Old_Units           0.273534
# Stu_Teach           0.177383
# Residential_Zone    0.175520
# Avg_Rooms           0.128069
# Bound               0.048788
# Name: Black_Prop, dtype: float64
#
# Low_Sts :
# Low_Sts             1.000000
# Target              0.737663
# Avg_Rooms           0.613808
# Business_Area       0.603800
# Old_Units           0.602339
# Nitric_Oxide        0.590879
# Tax                 0.543993
# Emp_Center          0.496996
# Highway             0.488676
# Crime_Rate          0.455621
# Residential_Zone    0.412995
# Stu_Teach           0.374044
# Black_Prop          0.366087
# Bound               0.053929
# Name: Low_Sts, dtype: float64

# %%
def linear_model(df):
    regr_model=LinearRegression()
    #x_train,x_test,y_train,y_test=np.array()
    x_train,x_test,y_train,y_test=train_test_split(df.iloc[:,:-1].values,df.iloc[:,-1:].values,test_size=0.2,random_state=6)
    print('features',df.columns[:-1],'\n')
    print("Shape of DataFrame, X-Test,X-Train,Y-Test,Y-Train\t: ",df.shape,x_train.shape, x_test.shape,y_train.shape,y_test.shape)

    regr_model.fit(x_train, y_train)
    y_predict = regr_model.predict(x_test)
    rmse = np.sqrt(mean_squared_error(y_test, y_predict))
    r2= r2_score(y_test, y_predict)
    #mean_absolute_error(y_test, y_predict)
    
    print('mae:',mean_absolute_error(y_test, y_predict))
    print('rmse & r2',rmse,r2)
    print('Slope\t:' ,regr_model.coef_)
    print('Intercept\t:', regr_model.intercept_)
    print("Test Score\t:",regr_model.score(x_test,y_test))
    print("Train Score\t:",regr_model.score(x_train,y_train))

# %%
linear_model(df_boston)
# Out:
# features Index(['Crime_Rate', 'Residential_Zone', 'Business_Area', 'Bound',
#        'Nitric_Oxide', 'Avg_Rooms', 'Old_Units', 'Emp_Center', 'Highway',
#        'Tax', 'Stu_Teach', 'Black_Prop', 'Low_Sts'],
#       dtype='object')
#
# Shape of DataFrame, X-Test,X-Train,Y-Test,Y-Train	:  (506, 14) (404, 13) (102, 13) (404, 1) (102, 1)
# mae: 3.811219584009737
# rmse & r2 5.217598463306335 0.683902689006904
# Slope	: [[-8.37706234e-02  5.26973316e-02 -2.99091142e-02  2.80173966e+00
#   -1.53320954e+01  3.36056709e+00  6.03391959e-03 -1.57441516e+00
#    3.48136303e-01 -1.48030305e-02 -9.87156291e-01  9.21978712e-03
#   -5.70626081e-01]]
# Intercept	: [40.2229734]
# Test Score	: 0.683902689006904
# Train Score	: 0.7515229944409221

# %%
df1=df_boston[['Avg_Rooms','Stu_Teach','Business_Area','Tax','Nitric_Oxide','Target']]
linear_model(df1)
# Out:
# features Index(['Avg_Rooms', 'Stu_Teach', 'Business_Area', 'Tax', 'Nitric_Oxide'], dtype='object')
#
# Shape of DataFrame, X-Test,X-Train,Y-Test,Y-Train	:  (506, 6) (404, 5) (102, 5) (404, 1) (102, 1)
# mae: 3.919281982371289
# rmse & r2 5.7074554884789475 0.6217625206778383
# Slope	: [[ 6.87332521e+00 -1.03499376e+00 -9.29710019e-03 -5.92955721e-03
#   -1.06099610e+01]]
# Intercept	: [6.90241463]
# Test Score	: 0.6217625206778383
# Train Score	: 0.6009480687525576

# %%
df2=df_boston[['Avg_Rooms','Stu_Teach','Business_Area','Target']]
linear_model(df2)
# Out:
# features Index(['Avg_Rooms', 'Stu_Teach', 'Business_Area'], dtype='object')
#
# Shape of DataFrame, X-Test,X-Train,Y-Test,Y-Train	:  (506, 4) (404, 3) (102, 3) (404, 1) (102, 1)
# mae: 4.259905047965236
# rmse & r2 5.972657674715365 0.5857955679057039
# Slope	: [[ 6.82934592 -1.07622385 -0.24396106]]
# Intercept	: [2.24526633]
# Test Score	: 0.5857955679057039
# Train Score	: 0.5844660245411164

# %%
from sklearn.preprocessing import RobustScaler
def scaling(df):
    trans= RobustScaler()
    data=trans.fit_transform(df)
    df_stand= pd.DataFrame(data,columns=df.columns)
    #print(df_stand.head())
    return(df_stand)

# %%
df_stand=scaling(df_boston)

# %%
df_stand.head()
# Out:
#    Crime_Rate  Residential_Zone  Business_Area  Bound  Nitric_Oxide  \
# 0   -0.069593              1.44      -0.571650    0.0      0.000000
# 1   -0.063755              0.00      -0.202943    0.0     -0.394286
# 2   -0.063760              0.00      -0.202943    0.0     -0.394286
# 3   -0.062347              0.00      -0.581720    0.0     -0.457143
# 4   -0.052144              0.00      -0.581720    0.0     -0.457143
#
#    Avg_Rooms  Old_Units  Emp_Center  Highway       Tax  Stu_Teach  Black_Prop  \
# 0   0.496612  -0.250765    0.285777    -0.20 -0.087855  -1.339286    0.261902
# 1   0.287940   0.028542    0.569789    -0.15 -0.227390  -0.446429    0.261902
# 2   1.323171  -0.334353    0.569789    -0.15 -0.227390  -0.446429    0.066675
# 3   1.069783  -0.646279    0.924391    -0.10 -0.279070  -0.125000    0.153016
# 4   1.271680  -0.475025    0.924391    -0.10 -0.279070  -0.125000    0.261902
#
#     Low_Sts    Target
# 0 -0.637681  0.351097
# 1 -0.221889  0.050157
# 2 -0.732634  1.692790
# 3 -0.841579  1.529781
# 4 -0.602699  1.880878

# %%
linear_model(df_stand)
# Out:
# features Index(['Crime_Rate', 'Residential_Zone', 'Business_Area', 'Bound',
#        'Nitric_Oxide', 'Avg_Rooms', 'Old_Units', 'Emp_Center', 'Highway',
#        'Tax', 'Stu_Teach', 'Black_Prop', 'Low_Sts'],
#       dtype='object')
#
# Shape of DataFrame, X-Test,X-Train,Y-Test,Y-Train	:  (506, 14) (404, 13) (102, 13) (404, 1) (102, 1)
# mae: 0.4778958726031036
# rmse & r2 0.6542443214177232 0.6839026890069031
# Slope	: [[-0.03776283  0.0825977  -0.04841714  0.35131532 -0.33644096  0.31098414
#    0.03711144 -0.6096787   0.8730691  -0.71834142 -0.34658779  0.02410151
#   -0.71587636]]
# Intercept	: [0.24098881]
# Test Score	: 0.6839026890069031
# Train Score	: 0.7515229944409221

# %%
for col in df_boston:    
    q_low = df_boston[col].quantile(0.05)
    q_hi  = df_boston[col].quantile(0.90)

    df_filtered = df_boston[(df_boston[col] < q_hi) & (df_boston[col] > q_low)]

# %%
df_filtered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 428 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Crime_Rate        428 non-null    float64
#  1   Residential_Zone  428 non-null    float64
#  2   Business_Area     428 non-null    float64
#  3   Bound             428 non-null    float64
#  4   Nitric_Oxide      428 non-null    float64
#  5   Avg_Rooms         428 non-null    float64
#  6   Old_Units         428 non-null    float64
#  7   Emp_Center        428 non-null    float64
#  8   Highway           428 non-null    float64
#  9   Tax               428 non-null    float64
#  10  Stu_Teach         428 non-null    float64
#  11  Black_Prop        428 non-null    float64
#  12  Low_Sts           428 non-null    float64
#  13  Target            428 non-null    float64
# dtypes: float64(14)
# memory usage: 50.2 KB

# %%
df_stand_fil=scaling(df_filtered)

# %%
linear_model(df_stand_fil)
# Out:
# features Index(['Crime_Rate', 'Residential_Zone', 'Business_Area', 'Bound',
#        'Nitric_Oxide', 'Avg_Rooms', 'Old_Units', 'Emp_Center', 'Highway',
#        'Tax', 'Stu_Teach', 'Black_Prop', 'Low_Sts'],
#       dtype='object')
#
# Shape of DataFrame, X-Test,X-Train,Y-Test,Y-Train	:  (428, 14) (342, 13) (86, 13) (342, 1) (86, 1)
# mae: 0.33791166221482377
# rmse & r2 0.4218549476201532 0.7046507575427605
# Slope	: [[-0.05051696  0.01523428 -0.03828017  0.1960214  -0.3609646   0.13564562
#   -0.18771559 -0.49751666  0.14128166 -0.2148944  -0.28335706  0.02216385
#   -0.45911007]]
# Intercept	: [0.11080563]
# Test Score	: 0.7046507575427605
# Train Score	: 0.7163390721223248

# %% [markdown]
# <h1>The Model is 70% efficient in Linear Regression Model
#
# RMSE: .42

# %%
from sklearn.linear_model import SGDRegressor
#df6=df[['BMI','Log_Serum_Triglyserides','BP','Tot_Cholesterol','High_Density_LipoProteins','Blood_Sugar_Level','target']]
def Grad_dsc(df):
    x1_train,x1_test,y1_train,y1_test=train_test_split(df.iloc[:,:-1].values,df.iloc[:,-1:].values,test_size=.1,random_state=6)
    x1_train,x1_test,y1_train,y1_test=x1_train,x1_test,y1_train.ravel(),y1_test.ravel()
    print(df.shape,x1_train.shape, x1_test.shape,y1_train.shape,y1_test.shape)

    g_desc= SGDRegressor(max_iter=10000,tol=1e-3) 
    g_desc.fit(x1_train,y1_train)
    y_predict = g_desc.predict(x1_test)
    rmse = np.sqrt(mean_squared_error(y1_test, y_predict))
    print('mae:',mean_absolute_error(y1_test, y_predict))
    print('rmse:',rmse)
    #print('rmse & r2 for Corr >.03 & 90/10',rmse5,r25)
    print(g_desc.score(x1_test,y1_test),g_desc.score(x1_train,y1_train),g_desc.coef_,g_desc.intercept_,g_desc.n_iter_,sep='\n')

# %%
Grad_dsc(df_stand_fil)
# Out:
# (428, 14) (385, 13) (43, 13) (385,) (43,)
# mae: 0.30468291188598046
# rmse: 0.3545071052241117
# 0.7283430824933845
# 0.7017345156276736
# [-0.04215889  0.0148152  -0.06680376  0.10071005 -0.20820045  0.16392891
#  -0.15440576 -0.26482976  0.1070049  -0.18684458 -0.26164022  0.01675986
#  -0.44685115]
# [0.09900068]
# 17

# %% [markdown]
# <h1>The Model is 72.8% efficient after applying Gradient Descent to find the best slope and intercepts as above
#
# RMSE: 0.35, It reduced compared to Linear regression

# %%
from sklearn import linear_model


def lasso_model(df):
    lasso_reg=linear_model.Lasso(alpha=5,max_iter=100,tol=0.1)
    #x_train,x_test,y_train,y_test=np.array()
    x_train,x_test,y_train,y_test=train_test_split(df.iloc[:,:-1].values,df.iloc[:,-1:].values,test_size=0.2,random_state=6)
    print('features',df.columns[:-1],'\n')
    print("Shape of DataFrame, X-Test,X-Train,Y-Test,Y-Train\t: ",df.shape,x_train.shape, x_test.shape,y_train.shape,y_test.shape)

    lasso_reg.fit(x_train, y_train)
    y_predict = lasso_reg.predict(x_test)
    rmse = np.sqrt(mean_squared_error(y_test, y_predict))
    print('Test score',lasso_reg.score(x_test,y_test))
    print('Train score',lasso_reg.score(x_train,y_train))
    print('rmse:',rmse)

# %%
lasso_model(df_boston)
# Out:
# features Index(['Crime_Rate', 'Residential_Zone', 'Business_Area', 'Bound',
#        'Nitric_Oxide', 'Avg_Rooms', 'Old_Units', 'Emp_Center', 'Highway',
#        'Tax', 'Stu_Teach', 'Black_Prop', 'Low_Sts'],
#       dtype='object')
#
# Shape of DataFrame, X-Test,X-Train,Y-Test,Y-Train	:  (506, 14) (404, 13) (102, 13) (404, 1) (102, 1)
# Test score 0.5469388063077267
# Train score 0.5649801707563882
# rmse: 6.246527917842286

# %% [markdown]
# <h1>The Model is 54% efficient for Lasso Regression (less than Linear Regression)
#
# RMSE: 6.2 (Higher than Linear regression after Gradient Descent)

# %%
from sklearn.linear_model import Ridge

def ridge_model(df):
    ridge_reg=Ridge(alpha=5,max_iter=100,tol=0.1)
    #x_train,x_test,y_train,y_test=np.array()
    x_train,x_test,y_train,y_test=train_test_split(df.iloc[:,:-1].values,df.iloc[:,-1:].values,test_size=0.2,random_state=6)
    print('features',df.columns[:-1],'\n')
    print("Shape of DataFrame, X-Test,X-Train,Y-Test,Y-Train\t: ",df.shape,x_train.shape, x_test.shape,y_train.shape,y_test.shape)

    ridge_reg.fit(x_train, y_train)
    y_predict = ridge_reg.predict(x_test)
    rmse = np.sqrt(mean_squared_error(y_test, y_predict))
    print('Test score',ridge_reg.score(x_test,y_test))
    print('Train score',ridge_reg.score(x_train,y_train))
    print('rmse:',rmse)

# %%
ridge_model(df_boston)
# Out:
# features Index(['Crime_Rate', 'Residential_Zone', 'Business_Area', 'Bound',
#        'Nitric_Oxide', 'Avg_Rooms', 'Old_Units', 'Emp_Center', 'Highway',
#        'Tax', 'Stu_Teach', 'Black_Prop', 'Low_Sts'],
#       dtype='object')
#
# Shape of DataFrame, X-Test,X-Train,Y-Test,Y-Train	:  (506, 14) (404, 13) (102, 13) (404, 1) (102, 1)
# Test score 0.6660262440264091
# Train score 0.7457281170137284
# rmse: 5.363106525415468

# %% [markdown]
# <h1>The Model is 66% efficient for Ridge Regression (less than Linear Regression)
#
# RMSE: 5.3 (Less than Lasso but still higher than Linear Regression)

# %% [markdown]
# <h1>Linear Regression with Gradient Descent gives the best model with 72.8% accuracy
#
# and RMSE also least among the other models 0.35
