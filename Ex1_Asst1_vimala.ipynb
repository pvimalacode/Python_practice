# %%
import deepface
import cv2
import os
import matplotlib.pyplot as plt
os.chdir("C:\\Users\\ponba\\OneDrive\\Desktop\\Vimala\\Loyalist\\subjects\\Ai for Canada\\asst")
os.getcwd()
# Out:
# 'C:\\Users\\ponba\\OneDrive\\Desktop\\Vimala\\Loyalist\\subjects\\Ai for Canada\\asst'

# %%
import seaborn as sns

# %%
img1_path="angelinajolie1.jpg"
img2_path="aj2.jpg"

img1=cv2.imread(img1_path)
img2=cv2.imread(img2_path)

plt.imshow(img1[:,:,::-1])
plt.show()
plt.imshow(img2[:,:,::-1])

# %%
import tensorflow
import keras
from deepface import DeepFace

# %%
result=DeepFace.verify(img1_path,img2_path)

# %%
result
# Out:
# {'verified': True,
#  'distance': 0.21241489173743977,
#  'max_threshold_to_verify': 0.4,
#  'model': 'VGG-Face',
#  'similarity_metric': 'cosine'}
